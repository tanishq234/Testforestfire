# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Algerian_forest_fires_cleaned_dataset.csv')

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.drop(['month','day','year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Classes'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       not fire
# 1       not fire
# 2       not fire
# 3       not fire
# 4       not fire
#            ...
# 238         fire
# 239     not fire
# 240     not fire
# 241     not fire
# 242    not fire
# Name: Classes, Length: 243, dtype: object>

# %%
#Encoding
df['Classes']=np.where(df['Classes'].str.contains("not fire"),0,1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
#independent and dependent featutre
X=df.drop('FWI',axis=1)
y=df['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
#feature selection basd on correlation
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# Temperature  0.390684  0.629848  0.473609  0.542141  0.254549
# RH          -0.236078 -0.717804 -0.362317 -0.456876 -0.394665
# Ws           0.096576 -0.023558  0.035633 -0.082570 -0.199969
# Rain        -0.302341 -0.345707 -0.300964 -0.369357 -0.059022
# FFMC         0.524101  0.750799  0.607210  0.781259  0.249514
# DMC          0.868647  0.685656  0.983175  0.617273  0.212582
# DC           1.000000  0.513701  0.942414  0.543581 -0.060838
# ISI          0.513701  1.000000  0.643818  0.742977  0.296441
# BUI          0.942414  0.643818  1.000000  0.612239  0.114897
# Classes      0.543581  0.742977  0.612239  1.000000  0.188837
# Region      -0.060838  0.296441  0.114897  0.188837  1.000000

# %%
#check for multicollinearity
plt.figure(figsize=(12,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
#threshold-domain expertise
corr_features=correlation(X_train,0.80)

# %%
#drop feature when correlation is more than 0.85
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %%
#Feature scaling or standardization

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -0.98907071],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526,  1.01105006],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  1.01105006],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -0.98907071],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  1.01105006],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -0.98907071]])

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('X_train before scaling')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train after scaling')
# Out:
# Text(0.5, 1.0, 'X_train after scaling')

# %%
#Apply linear regression model

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred=linreg.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.5468236465249978
# R2 score 0.9847657384266951

# %%
#Apply lasso regression

from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso=Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred=lasso.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 1.133175994914409
# R2 score 0.9492020263112388

# %%
#Cross validation lasso
from sklearn.linear_model import LassoCV
lassoCV=LassoCV()
lassoCV.fit(X_train,y_train)
# Out:
# LassoCV()

# %%
lassoCV.alphas_
# Out:
# array([85.00906654, 79.27973997, 73.93655083, 68.95347477, 64.30624135,
#        59.9722159 , 55.93028927, 52.16077497, 48.64531331, 45.366782  ,
#        42.30921273, 39.4577134 , 36.79839558, 34.31830688, 32.00536785,
#        29.84831318, 27.83663677, 25.96054061, 24.21088706, 22.57915431,
#        21.05739488, 19.63819694, 18.31464819, 17.0803022 , 15.929147  ,
#        14.8555758 , 13.85435971, 12.92062224, 12.04981554, 11.2376983 ,
#        10.48031505,  9.77397689,  9.11524356,  8.50090665,  7.927974  ,
#        [ 1.05150409,  1.98868622,  6.51500708,  2.64197086,  1.1627778 ],
#        [ 1.02364907,  1.95392803,  6.63469354,  2.58941912,  1.13372036],
#        [ 0.99862678,  1.92213239,  6.74877413,  2.54158876,  1.10726131],
#        [ 0.9761425 ,  1.89301887,  6.85649976,  2.49800788,  1.08314218],
#        [ 0.95591243,  1.86633648,  6.95961227,  2.4585411 ,  1.06113274],
#        [ 0.93768847,  1.84186029,  7.05740509,  2.42222676,  1.04135117],
#        [ 0.9212517 ,  1.81938848,  7.15001577,  2.3890334 ,  1.02294657],
#        [ 0.90640888,  1.79885711,  7.23760989,  2.35944212,  1.00763994],
#        [ 0.89298924,  1.77985871,  7.32036599,  2.3325068 ,  0.99957941],
#        [ 0.88087123,  1.76237569,  7.39847134,  2.30783974,  0.99235282],
#        [ 0.86985699,  1.74627402,  7.47117809,  2.28523421,  0.98619174],
#        [ 0.85986547,  1.73143414,  7.54060441,  2.26449174,  0.98031804],
#        [ 0.85078946,  1.71774801,  7.60597717,  2.24572898,  0.97500805],
#        [ 0.84253571,  1.70511786,  7.66747558,  2.2281976 ,  0.97020957],
#        [ 0.8350214 ,  1.69315491,  7.72529108,  2.21207385,  0.96586875],
#        [ 0.82817282,  1.68150637,  7.77961172,  2.19723137,  0.96193728],
#        [ 0.82192436,  1.67090759,  7.83062072,  2.18355834,  0.95837236],
#        [ 0.81625769,  1.66101827,  7.87849575,  2.17095393,  0.9554834 ],
#        [ 0.81103395,  1.65190155,  7.92241739,  2.15932694,  0.9525328 ],
#        [ 0.80625601,  1.64349209,  7.96457385,  2.14859485,  0.94983433],
#        [ 0.80159373,  1.63573019,  8.00411035,  2.13896825,  0.94737463],
#        [ 0.79385802,  1.6285617 ,  8.04115772,  2.12978953,  0.94513124],
#        [ 0.779252  ,  1.61356202,  8.07585989,  2.12130113,  0.94308309],
#        [ 0.76683338,  1.59559653,  8.10868742,  2.11344899,  0.93530344],
#        [ 0.75641319,  1.58028465,  8.13972047,  2.10618154,  0.914851  ],
#        [ 0.74752807,  1.5670096 ,  8.13629471,  2.09945213,  0.89715546],
#        [ 0.74010394,  1.55562177,  8.13484626,  2.09321822,  0.88118391],
#        [ 0.73392831,  1.54586408,  8.13281834,  2.0877327 ,  0.86703321],
#        [ 0.7301259 ,  1.53751431,  8.13219644,  2.07154561,  0.85449087],
#        [ 0.72746931,  1.53037985,  8.13217764,  2.03775222,  0.84336352],
#        [ 0.72558391,  1.52421009,  8.13260958,  2.01016718,  0.8334816 ],
#        [ 0.72441432,  1.51883301,  8.1343861 ,  1.98509527,  0.82469664],
#        [ 0.72404057,  1.51418915,  8.13676573,  1.96680696,  0.81687857]])

# %%
y_pred=lassoCV.predict(X_test_scaled)
plt.scatter(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
# Out:
# c:\Users\hp\OneDrive\Desktop\Udemy Krish_Naik ML\venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LassoCV was fitted with feature names
#   warnings.warn(
# Mean absolute error 6.47731726130616
# R2 score -0.6584221814898077

# %%
#Apply ridge regression

from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.5642305340105715
# R2 score 0.9842993364555512

# %%
from sklearn.linear_model import RidgeCV
ridgeCV=RidgeCV()
ridgeCV.fit(X_train_scaled,y_train)
y_pred=ridgeCV.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.5642305340106358
# R2 score 0.9842993364555516

# %%
ridgeCV.alphas
# Out:
# (0.1, 1.0, 10.0)

# %%
ridgeCV.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': None,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': None,
#  'store_cv_values': 'deprecated'}

# %%
#Apply elasticnet regression

from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elasticnet=ElasticNet()
elasticnet.fit(X_train_scaled,y_train)
y_pred=elasticnet.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 1.8822353634896005
# R2 score 0.8753460589519703

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elasticCV=ElasticNetCV()
elasticCV.fit(X_train_scaled,y_train)
y_pred=elasticCV.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error",mae)
print("R2 score",score)
plt.scatter(y_test,y_pred)
# Out:
# Mean absolute error 0.6575946731430898
# R2 score 0.9814217587854941

# %%
elasticCV.alphas_
# Out:
# array([14.11706004, 13.16561744, 12.27829889, 11.45078264, 10.67903821,
#         9.95930678,  9.28808283,  8.66209714,  8.07830078,  7.53385034,
#         7.02609405,  6.55255882,  6.11093829,  5.6990815 ,  5.31498248,
#         4.95677045,  4.62270071,  4.31114616,  4.02058933,  3.74961507,
#         3.49690356,  3.26122397,  3.04142839,  2.83644629,  2.64527931,
#         2.46699633,  2.30072904,  2.1456676 ,  2.00105679,  1.86619226,
#         1.74041714,  1.62311885,  1.51372607,  1.411706  ,  1.31656174,
#         1.22782989,  1.14507826,  1.06790382,  0.99593068,  0.92880828,
#         0.86620971,  0.80783008,  0.75338503,  0.7026094 ,  0.65525588,
#         0.61109383,  0.56990815,  0.53149825,  0.49567705,  0.46227007,
#         0.43111462,  0.40205893,  0.37496151,  0.34969036,  0.3261224 ,
#         0.30414284,  0.28364463,  0.26452793,  0.24669963,  0.2300729 ,
#         0.21456676,  0.20010568,  0.18661923,  0.17404171,  0.16231189,
#         0.15137261,  0.1411706 ,  0.13165617,  0.12278299,  0.11450783,
#         0.10679038,  0.09959307,  0.09288083,  0.08662097,  0.08078301,
#         0.0753385 ,  0.07026094,  0.06552559,  0.06110938,  0.05699082,
#         0.05314982,  0.0495677 ,  0.04622701,  0.04311146,  0.04020589,
#         0.03749615,  0.03496904,  0.03261224,  0.03041428,  0.02836446,
#         0.02645279,  0.02466996,  0.02300729,  0.02145668,  0.02001057,
#         0.01866192,  0.01740417,  0.01623119,  0.01513726,  0.01411706])

# %%
#pickling machine learning models,preprocessing models standard scaler
scaler
# Out:
# StandardScaler()

# %%
ridge
# Out:
# Ridge()

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))
